# %%
# !pip install -q pandas matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 52.3 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 47.2 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 46.2 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 42.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 84.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.9/301.9 kB 41.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 70.2 MB/s eta 0:00:00ta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 71.5 MB/s eta 0:00:00a 0:00:01
# ...

# %%
import pandas as pd
import matplotlib
import json

# %%
result_file = '../data/result_log/[damage_label0]train_log.json'

with open(result_file, 'r') as f:
    result_json = json.load(f)

# %%
result_json
# Out:
# {'comand': 'python main.py --train train --task damage --label all',
#  'start_at_kst': '2023-10-11 23:05:59 KST+0900',
#  'end_at_kst': '2023-10-12 00:49:46 KST+0900',
#  'train_log': [{'epoch': 1,
#    'train_loss': [0.817625105381012,
#     0.2703307569026947,
#     0.2301539033651352,
#     0.22584964334964752,
#     0.2186800241470337,
#     0.2070116102695465,
#     0.1825878769159317,
#     0.19387221336364746],
#    'eval': {'img': [{'img_id': '0212865_as-3046144.jpg',
#       'IoU': [0.9217927393142177, 0.0009746588693957114]},
#      {'img_id': '0239212_sc-105513.jpg',
#       'IoU': [0.9565075618769603, 0.28818297331639137]},
#      {'img_id': '0249332_as-0050686.jpg', 'IoU': [0.9972686767578125, 0.0]},
#      {'img_id': '0159968_as-3245080.jpg',
#       'IoU': [0.8223356009070295, 0.25709448018963765]},
#      {'img_id': '0168007_as-0080226.jpg',
#       'IoU': [0.9825928534247834, 0.16088560885608857]},
#      {'img_id': '0362527_sc-224808.jpg',
# ...

# %%
results = []
for r in result_json['train_log']:
    tmp = {}
    tmp['epoch'] = r['epoch']
    tmp['train_step_losses'] = r['train_loss']
    tmp['eval_summary'] = r['eval']['summary']
    results.append(tmp)
results
# Out:
# [{'epoch': 1,
#   'train_step_losses': [0.817625105381012,
#    0.2703307569026947,
#    0.2301539033651352,
#    0.22584964334964752,
#    0.2186800241470337,
#    0.2070116102695465,
#    0.1825878769159317,
#    0.19387221336364746],
#   'eval_summary': {'mIoU': 0.646469885533127,
#    'average Loss': 0.18156033754348755,
#    'background IoU': 0.9598566057534715,
#    'target IoU': 0.3330831653127825,
#    'end_at_kst': '2023-10-11 23:58:10 KST+0900'}},
#  {'epoch': 2,
#   'train_step_losses': [0.17660275101661682,
#    0.1725434958934784,
#    0.15113455057144165,
#    0.16685765981674194,
#    0.13973501324653625,
#    0.14181162416934967,
#    0.15236449241638184,
#    0.16208460927009583],
#   'eval_summary': {'mIoU': 0.6789926187155867,
#    'average Loss': 0.136949360370636,
#    'background IoU': 0.9623577846713289,
#    'target IoU': 0.3956274527598445,
#    'end_at_kst': '2023-10-12 00:49:46 KST+0900'}}]

# %%
df = pd.read_json('..//data/result_log/[damage_label0]train_log.json')
df
# Out:
#                                               comand  \
# 0  python main.py --train train --task damage --l...
# 1  python main.py --train train --task damage --l...
#
#                    start_at_kst                    end_at_kst  \
# 0  2023-10-11 23:05:59 KST+0900  2023-10-12 00:49:46 KST+0900
# 1  2023-10-11 23:05:59 KST+0900  2023-10-12 00:49:46 KST+0900
#
#                                            train_log
# 0  {'epoch': 1, 'train_loss': [0.8176251053810121...
# 1  {'epoch': 2, 'train_loss': [0.1766027510166160...

# %%
from matplotlib.pylab import plt
from numpy import arange
 
# Load the training and validation loss dictionaries
train_loss = load(open('train_loss.pkl', 'rb'))
val_loss = load(open('val_loss.pkl', 'rb'))
 
# Retrieve each dictionary's values
train_values = train_loss.values()
val_values = val_loss.values()
 
# Generate a sequence of integers to represent the epoch numbers
epochs = range(1, 21)
 
# Plot and label the training and validation loss values
plt.plot(epochs, train_values, label='Training Loss')
plt.plot(epochs, val_values, label='Validation Loss')
 
# Add in a title and axes labels
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
 
# Set the tick locations
plt.xticks(arange(0, 21, 2))
 
# Display the plot
plt.legend(loc='best')
plt.show()
